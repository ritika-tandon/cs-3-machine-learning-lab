# %% [markdown]
# <a href="https://colab.research.google.com/github/ritika-tandon/cs-3-machine-learning-lab/blob/master/read_writecv.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install opencv-python

# %%
import cv2

# %%
cv2.__version__
# Out:
# '4.1.2'

# %%
from google.colab.patches import cv2_imshow
#img=cv2.imread('opencv.png',-1)
#img=cv2.imread('opencv.png',1)
img=cv2.imread('opencv.png',0)
print(img)
cv2_imshow( img)
cv2.waitKey(0)
#if k==27: foe esc key
#  cv2.destroyAllWindows()
#elif k==ord('s'):
cv2.imwrite('copy.png',img)
cv2.destroyAllWindows()
# Out:
# [[119 119 119 ...  87  84  84]
#  [120 120 120 ...  87  87  87]
#  [122 122 123 ...  89  89  89]
#  ...
#  [ 28  28   0 ...   0   0   0]
#  [ 28  28   0 ...   0   0   0]
#  [ 28  28   0 ...   0   0   0]]
# <PIL.Image.Image image mode=L size=321x340 at 0x7FB31E290048>
